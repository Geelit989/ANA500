# %%
import numpy as np
import matplotlib as mpl
import pandas as pd
import os 
from matplotlib import pyplot as plt

# %% [markdown]
# #IMPORT FILE

# %%
nasa = pd.read_csv('/Users/duk3y2/Library/CloudStorage/OneDrive-Personal/Documents/ANA500/WK_4/archive (1)/DailyDelhiClimateTrain.csv', index_col='date', parse_dates=True)
nasa.index.freq = 'D'

# %%
nasa.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
nasa['meantemp'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
results = seasonal_decompose(nasa['meantemp'])
results.plot();

# %%
len(nasa)
# Out:
# 1462

# %%
train = nasa.iloc[:1097]
test = nasa.iloc[1097:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
nasa.head(),nasa.tail()
# Out:
# (             meantemp   humidity  wind_speed  meanpressure
#  date
#  2013-01-01  10.000000  84.500000    0.000000   1015.666667
#  2013-01-02   7.400000  92.000000    2.980000   1017.800000
#  2013-01-03   7.166667  87.000000    4.633333   1018.666667
#  2013-01-04   8.666667  71.333333    1.233333   1017.166667
#  2013-01-05   6.000000  86.833333    3.700000   1016.500000,
#               meantemp    humidity  wind_speed  meanpressure
#  date
#  2016-12-28  17.217391   68.043478    3.547826   1015.565217
#  2016-12-29  15.238095   87.857143    6.000000   1016.904762
#  2016-12-30  14.095238   89.666667    6.266667   1017.904762
#  2016-12-31  15.052632   87.000000    7.325000   1016.100000
#  2017-01-01  10.000000  100.000000    0.000000   1016.000000)

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
scaled_train[:10]
# Out:
# array([[0.12227074, 0.84037162, 0.        , 0.76811594],
#        [0.04279476, 0.92905405, 0.07058266, 0.83557312],
#        [0.0356623 , 0.86993243, 0.10974262, 0.8629776 ],
#        [0.08151383, 0.68468468, 0.02921206, 0.81554677],
#        [0.        , 0.86796171, 0.08763619, 0.7944664 ],
#        [0.03056769, 0.82027027, 0.03505448, 0.84189723],
#        [0.03056769, 0.77060811, 0.14921838, 0.90513834],
#        [0.08733624, 0.59459459, 0.16918184, 0.86448334],
#        [0.24454148, 0.44721284, 0.29606821, 0.81027668],
#        [0.15283843, 0.57432432, 0.17527238, 0.76811594]])

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 from keras.preprocessing.sequence import TimeseriesGenerator
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/__init__.py:21, in <module>
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python import tf2
#      22 from keras import distribute
#      24 from keras import models
#
# ModuleNotFoundError: No module named 'tensorflow'
